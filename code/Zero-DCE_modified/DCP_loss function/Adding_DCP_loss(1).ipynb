# %%
# !git clone https://github.com/Thehunk1206/Zero-DCE.git
# Out:
# Cloning into 'Zero-DCE'...
# remote: Enumerating objects: 373, done.
# remote: Counting objects: 100% (372/372), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 373 (delta 171), reused 356 (delta 158), pack-reused 1
# Receiving objects: 100% (373/373), 59.22 MiB | 23.46 MiB/s, done.
# Resolving deltas: 100% (171/171), done.

# %%
# %cd Zero-DCE
# !mkdir dataset_v 
# !mkdir dataset200
# Out:
# /content/Zero-DCE

# %%
# !mkdir validate

# %%
# %cd validate
# !mkdir high15
# !mkdir low
# !mkdir high
# Out:
# /content/Zero-DCE/validate

# %%
# %cd /content/Zero-DCE
# Out:
# /content/Zero-DCE

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
import tensorflow as tf
from tqdm import tqdm

# %%
from skimage import metrics, transform
import cv2
import glob

# %% [markdown]
# #DCP_loss with weight=0.001

# %%
"""Parameters
weights of DCP_loss=0.001
      Dataset_size=56
      Epoch=40
      learning rate=1e-3
      filters=32
        """

# !python train_model.py --dataset_dir dataset_v/ \
                       --model_type zero_dce \
                       --checkpoint_dir Trained_model/ \
                       --IMG_H 512 \
                       --IMG_W 512 \
                       --epoch 40\
                       --batch_size 4 \
                       --learning_rate 0.001 \
                       --filters 32 \
                       --iteration 8
# Out:
# Creating dataset pipeline...
#
# Creating Zero-DCE model...
#
# Compiling the model...
#
# [INFO] Summary of model
#
# Model: "DCE-net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 512, 512, 64  0           ['conv2d_2[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 512, 512, 32  18464       ['concatenate[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_1[0][0]',
#                                 )                                 'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 512, 512, 32  18464       ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 512, 512, 64  0           ['conv2d[0][0]',
#                                 )                                 'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 24  13848       ['concatenate_2[0][0]']
#                                 )
#
#  tf.math.square (TFOpLambda)    (None, 512, 512, 3)  0           ['input_1[0][0]']
#
#  tf.split (TFOpLambda)          [(None, 512, 512, 3  0           ['conv2d_6[0][0]']
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 )]
#
#  tf.math.subtract (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.math.square[0][0]',
#                                                                   'input_1[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.split[0][0]',
#                                                                   'tf.math.subtract[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 512, 512, 3)  0          ['input_1[0][0]',
#  da)                                                              'tf.math.multiply[0][0]']
#
#  tf.math.square_1 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_1[0][0]',
#  )                                                                'tf.__operators__.add[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][1]',
#  )                                                                'tf.math.subtract_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add[0][0]',
#  mbda)                                                            'tf.math.multiply_1[0][0]']
#
#  tf.math.square_2 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_2[0][0]',
#  )                                                                'tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][2]',
#  )                                                                'tf.math.subtract_2[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_1[0][0]',
#  mbda)                                                            'tf.math.multiply_2[0][0]']
#
#  tf.math.square_3 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_3[0][0]',
#  )                                                                'tf.__operators__.add_2[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][3]',
#  )                                                                'tf.math.subtract_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'tf.math.multiply_3[0][0]']
#
#  tf.math.square_4 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_4[0][0]',
#  )                                                                'tf.__operators__.add_3[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][4]',
#  )                                                                'tf.math.subtract_4[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_3[0][0]',
#  mbda)                                                            'tf.math.multiply_4[0][0]']
#
#  tf.math.square_5 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.subtract_5 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_5[0][0]',
#  )                                                                'tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][5]',
#  )                                                                'tf.math.subtract_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_4[0][0]',
#  mbda)                                                            'tf.math.multiply_5[0][0]']
#
#  tf.math.square_6 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_5[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_6[0][0]',
#  )                                                                'tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][6]',
#  )                                                                'tf.math.subtract_6[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_5[0][0]',
#  mbda)                                                            'tf.math.multiply_6[0][0]']
#
#  tf.math.square_7 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_6[0][0]']
#
#  tf.math.subtract_7 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_7[0][0]',
#  )                                                                'tf.__operators__.add_6[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][7]',
#  )                                                                'tf.math.subtract_7[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_6[0][0]',
#  mbda)                                                            'tf.math.multiply_7[0][0]']
#
# ==================================================================================================
# Total params: 79,416
# Trainable params: 79,416
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
#
#
# ************************************************************
# 			Model Configs
# ************************************************************
#
#  Model Name                : DCE-Net
#  Input shape               : ((512, 512, 3))
#  Epochs                    : 40
#  Batch Size                : 4
#  Learning Rate             : 0.001
#  Dataset Split             : 0.05
#  Post enhancing Iteration  : 8
#
#
# Training the model...
#
# training...: 100% 13/13 [00:14<00:00,  1.12s/steps]
# validating...: 100% 1/1 [00:00<00:00,  1.13steps/s]
# ETA:0.26 - epoch: 1 - loss: 255.89479064941406  val_loss: 158.52154541015625
#
# Writing logs to TensorBoard...
#
# loss: 255.89479064941406
# DCP-loss: 45.9874382019043
# spatial_consistency_loss: 0.7919555306434631
# exposure_control_loss: 3.03251051902771
# color_constancy_loss: 0.012427582405507565
# illumination_smoothness_loss: 206.07044982910156
#
#
# val_loss: 158.52154541015625
# val_DCP-loss: 6.346334934234619
# val_spatial_consistency_loss: 0.7606814503669739
# val_exposure_control_loss: 3.152104377746582
# val_color_constancy_loss: 0.0017184396274387836
# val_illumination_smoothness_loss: 148.26071166992188
#
#
# training...: 100% 13/13 [00:02<00:00,  4.50steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.41steps/s]
# ETA:0.05 - epoch: 2 - loss: 9.446538925170898  val_loss: 4.287150859832764
#
# Writing logs to TensorBoard...
#
# loss: 9.446538925170898
# DCP-loss: 5.403271675109863
# spatial_consistency_loss: 0.8431336879730225
# exposure_control_loss: 3.1968836784362793
# color_constancy_loss: 2.046418103418546e-06
# illumination_smoothness_loss: 0.003248586319386959
#
#
# val_loss: 4.287150859832764
# val_DCP-loss: 0.31824666261672974
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.00044730413355864584
#
#
# training...: 100% 13/13 [00:02<00:00,  4.59steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.35steps/s]
# ETA:0.05 - epoch: 3 - loss: 4.8667097091674805  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 4.8667097091674805
# DCP-loss: 0.9174067974090576
# spatial_consistency_loss: 0.749412477016449
# exposure_control_loss: 3.19989013671875
# color_constancy_loss: 3.306991347429289e-09
# illumination_smoothness_loss: 1.920711589775692e-09
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 2.45653666297585e-08
#
#
# training...: 100% 13/13 [00:02<00:00,  4.58steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.31steps/s]
# ETA:0.05 - epoch: 4 - loss: 4.794308662414551  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 4.794308662414551
# DCP-loss: 0.8992083072662354
# spatial_consistency_loss: 0.6951754689216614
# exposure_control_loss: 3.199925184249878
# color_constancy_loss: 2.1349364498490786e-09
# illumination_smoothness_loss: 5.63003116349492e-12
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 3.1472399686371944e-10
#
#
# training...: 100% 13/13 [00:02<00:00,  4.56steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.35steps/s]
# ETA:0.05 - epoch: 5 - loss: 16.42159652709961  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 16.42159652709961
# DCP-loss: 12.294147491455078
# spatial_consistency_loss: 0.9636569023132324
# exposure_control_loss: 3.163543701171875
# color_constancy_loss: 0.00024911563377827406
# illumination_smoothness_loss: 1.7599002255508367e-09
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 7.539281698942801e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.56steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.32steps/s]
# ETA:0.05 - epoch: 6 - loss: 5.86293888092041  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.86293888092041
# DCP-loss: 1.7321655750274658
# spatial_consistency_loss: 0.9334822297096252
# exposure_control_loss: 3.1972899436950684
# color_constancy_loss: 1.4387646842806134e-06
# illumination_smoothness_loss: 2.13725342979032e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.987652998944547e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.56steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.29steps/s]
# ETA:0.05 - epoch: 7 - loss: 5.665838241577148  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.665838241577148
# DCP-loss: 1.5022611618041992
# spatial_consistency_loss: 0.9640551209449768
# exposure_control_loss: 3.199522018432617
# color_constancy_loss: 3.2734529753497554e-08
# illumination_smoothness_loss: 2.628672453319769e-12
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824666261672974
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.411320614350345e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.55steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.32steps/s]
# ETA:0.05 - epoch: 8 - loss: 6.563084602355957  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 6.563084602355957
# DCP-loss: 2.5308868885040283
# spatial_consistency_loss: 0.8353474140167236
# exposure_control_loss: 3.1968486309051514
# color_constancy_loss: 2.032890733971726e-06
# illumination_smoothness_loss: 1.6384052448081832e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.332596434397651e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.54steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.32steps/s]
# ETA:0.05 - epoch: 9 - loss: 6.484882354736328  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 6.484882354736328
# DCP-loss: 2.4076430797576904
# spatial_consistency_loss: 0.8779191970825195
# exposure_control_loss: 3.199320077896118
# color_constancy_loss: 3.7872716518450034e-08
# illumination_smoothness_loss: 3.862297981438445e-11
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.250087781709766e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.53steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.29steps/s]
# ETA:0.05 - epoch: 10 - loss: 4.531633377075195  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 4.531633377075195
# DCP-loss: 0.56935054063797
# spatial_consistency_loss: 0.7623506188392639
# exposure_control_loss: 3.199932336807251
# color_constancy_loss: 3.209394416892053e-10
# illumination_smoothness_loss: 1.7064551161016794e-11
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.230146441464022e-11
#
#
# Saving model at epoch 10...
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Saved model at epoch 10
#
# training...: 100% 13/13 [00:02<00:00,  4.52steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.25steps/s]
# ETA:0.05 - epoch: 11 - loss: 5.168851852416992  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.168851852416992
# DCP-loss: 1.104838490486145
# spatial_consistency_loss: 0.8642911911010742
# exposure_control_loss: 3.1997225284576416
# color_constancy_loss: 1.3670229392914734e-08
# illumination_smoothness_loss: 1.5194852320821184e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.270478415335788e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.51steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.29steps/s]
# ETA:0.05 - epoch: 12 - loss: 4.406755447387695  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 4.406755447387695
# DCP-loss: 0.540458083152771
# spatial_consistency_loss: 0.6663340926170349
# exposure_control_loss: 3.199963331222534
# color_constancy_loss: 4.810385978437637e-10
# illumination_smoothness_loss: 9.710418233388474e-13
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824666261672974
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.230146441464022e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.48steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.26steps/s]
# ETA:0.05 - epoch: 13 - loss: 7.547946453094482  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 7.547946453094482
# DCP-loss: 3.4539613723754883
# spatial_consistency_loss: 0.8956587910652161
# exposure_control_loss: 3.1983258724212646
# color_constancy_loss: 5.20996252362238e-07
# illumination_smoothness_loss: 1.0582119208679686e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824666261672974
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.230146441464022e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.51steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.25steps/s]
# ETA:0.05 - epoch: 14 - loss: 18.636001586914062  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 18.636001586914062
# DCP-loss: 14.52619457244873
# spatial_consistency_loss: 0.9474257826805115
# exposure_control_loss: 3.1621315479278564
# color_constancy_loss: 0.0002496425004210323
# illumination_smoothness_loss: 1.0668345096220833e-09
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824666261672974
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.246492046888761e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.50steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.30steps/s]
# ETA:0.05 - epoch: 15 - loss: 5.752851486206055  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.752851486206055
# DCP-loss: 1.584592342376709
# spatial_consistency_loss: 0.9705920219421387
# exposure_control_loss: 3.1976654529571533
# color_constancy_loss: 1.3640583347296342e-06
# illumination_smoothness_loss: 1.4862024111383931e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824666261672974
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.250087781709766e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.49steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.23steps/s]
# ETA:0.05 - epoch: 16 - loss: 9.90847396850586  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 9.90847396850586
# DCP-loss: 5.759195804595947
# spatial_consistency_loss: 0.9544957280158997
# exposure_control_loss: 3.19477915763855
# color_constancy_loss: 3.4033985230053077e-06
# illumination_smoothness_loss: 6.478416691990674e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.2320150855923444e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.46steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.21steps/s]
# ETA:0.05 - epoch: 17 - loss: 7.249338150024414  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 7.249338150024414
# DCP-loss: 3.0498058795928955
# spatial_consistency_loss: 1.0014088153839111
# exposure_control_loss: 3.198122501373291
# color_constancy_loss: 7.342423486988991e-07
# illumination_smoothness_loss: 1.6963329352304157e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.2523585347398196e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.47steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.28steps/s]
# ETA:0.05 - epoch: 18 - loss: 5.548816204071045  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.548816204071045
# DCP-loss: 1.4490104913711548
# spatial_consistency_loss: 0.9000608921051025
# exposure_control_loss: 3.1997451782226562
# color_constancy_loss: 1.5440100753494335e-08
# illumination_smoothness_loss: 1.6149689224809194e-11
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.251956425838088e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.47steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.26steps/s]
# ETA:0.05 - epoch: 19 - loss: 17.416433334350586  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 17.416433334350586
# DCP-loss: 13.190813064575195
# spatial_consistency_loss: 1.0638796091079712
# exposure_control_loss: 3.1614904403686523
# color_constancy_loss: 0.00025046186055988073
# illumination_smoothness_loss: 1.2769032498027855e-09
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.246492046888761e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.47steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.25steps/s]
# ETA:0.05 - epoch: 20 - loss: 5.637359142303467  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.637359142303467
# DCP-loss: 1.5792754888534546
# spatial_consistency_loss: 0.858406126499176
# exposure_control_loss: 3.1996772289276123
# color_constancy_loss: 1.551339323668799e-08
# illumination_smoothness_loss: 1.5429688082768678e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.2468941557904927e-11
#
#
# Saving model at epoch 20...
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Saved model at epoch 20
#
# training...: 100% 13/13 [00:02<00:00,  4.46steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.26steps/s]
# ETA:0.05 - epoch: 21 - loss: 5.752264022827148  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.752264022827148
# DCP-loss: 1.6826063394546509
# spatial_consistency_loss: 0.8718891143798828
# exposure_control_loss: 3.1977672576904297
# color_constancy_loss: 1.3541248335968703e-06
# illumination_smoothness_loss: 3.3483518735444306e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4
-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.2252260717967616e-11
#
#
# Saving model at epoch 30...
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Saved model at epoch 30
#
# training...: 100% 13/13 [00:02<00:00,  4.39steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.06steps/s]
# ETA:0.05 - epoch: 31 - loss: 6.786673545837402  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 6.786673545837402
# DCP-loss: 2.6368215084075928
# spatial_consistency_loss: 0.9512176513671875
# exposure_control_loss: 3.198634147644043
# color_constancy_loss: 6.990393899286573e-07
# illumination_smoothness_loss: 2.2519711095903006e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.250087781709766e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.37steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.13steps/s]
# ETA:0.05 - epoch: 32 - loss: 4.88710355758667  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 4.88710355758667
# DCP-loss: 0.9233769774436951
# spatial_consistency_loss: 0.7638365626335144
# exposure_control_loss: 3.199889898300171
# color_constancy_loss: 3.3236469132447155e-09
# illumination_smoothness_loss: 7.130829130300165e-13
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824666261672974
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.274263235015674e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.35steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.08steps/s]
# ETA:0.05 - epoch: 33 - loss: 5.296112060546875  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.296112060546875
# DCP-loss: 1.2442889213562012
# spatial_consistency_loss: 0.8520624041557312
# exposure_control_loss: 3.199760675430298
# color_constancy_loss: 6.78155576139261e-09
# illumination_smoothness_loss: 8.15474007764827e-11
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.232417194494076e-11
#
#
# training...: 100% 13/13 [00:02<00:00,  4.34steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.08steps/s]
# ETA:0.05 - epoch: 34 - loss: 5.408003330230713  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.408003330230713
# DCP-loss: 1.3972722291946411
# spatial_consistency_loss: 0.8110930323600769
# exposure_control_loss: 3.1996381282806396
# color_constancy_loss: 1.957882744818562e-08
# illumination_smoothness_loss: 7.834308202170348e-11
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.230146441464022e-11
#
#
# training...: 100% 13/13 [00:03<00:00,  4.32steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.15steps/s]
# ETA:0.05 - epoch: 35 - loss: 5.219152450561523  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.219152450561523
# DCP-loss: 1.155651569366455
# spatial_consistency_loss: 0.8637943863868713
# exposure_control_loss: 3.1997063159942627
# color_constancy_loss: 1.2893197620655883e-08
# illumination_smoothness_loss: 6.615562264666863e-11
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.2305485503657536e-11
#
#
# training...: 100% 13/13 [00:03<00:00,  4.31steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.06steps/s]
# ETA:0.05 - epoch: 36 - loss: 5.7827935218811035  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 5.7827935218811035
# DCP-loss: 1.6750296354293823
# spatial_consistency_loss: 0.9099326133728027
# exposure_control_loss: 3.197829484939575
# color_constancy_loss: 1.3542010037781438e-06
# illumination_smoothness_loss: 1.5021850430230188e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824666261672974
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.230146441464022e-11
#
#
# training...: 100% 13/13 [00:03<00:00,  4.30steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.08steps/s]
# ETA:0.05 - epoch: 37 - loss: 6.016924858093262  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 6.016924858093262
# DCP-loss: 1.993975281715393
# spatial_consistency_loss: 0.8234131932258606
# exposure_control_loss: 3.1995365619659424
# color_constancy_loss: 2.9167306792032832e-08
# illumination_smoothness_loss: 5.612171968469304e-13
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.230146441464022e-11
#
#
# training...: 100% 13/13 [00:03<00:00,  4.31steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.07steps/s]
# ETA:0.05 - epoch: 38 - loss: 7.046815395355225  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 7.046815395355225
# DCP-loss: 2.8575921058654785
# spatial_consistency_loss: 0.9912577271461487
# exposure_control_loss: 3.197965145111084
# color_constancy_loss: 6.086479515943211e-07
# illumination_smoothness_loss: 3.960431288474453e-11
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824666261672974
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.250087781709766e-11
#
#
# training...: 100% 13/13 [00:03<00:00,  4.30steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.13steps/s]
# ETA:0.05 - epoch: 39 - loss: 6.0527448654174805  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 6.0527448654174805
# DCP-loss: 2.005314826965332
# spatial_consistency_loss: 0.8479363322257996
# exposure_control_loss: 3.199493885040283
# color_constancy_loss: 3.1519821419578875e-08
# illumination_smoothness_loss: 5.198512731396931e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824666261672974
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.244765303140774e-11
#
#
# training...: 100% 13/13 [00:03<00:00,  4.31steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.09steps/s]
# ETA:0.05 - epoch: 40 - loss: 6.865839958190918  val_loss: 4.286703586578369
#
# Writing logs to TensorBoard...
#
# loss: 6.865839958190918
# DCP-loss: 2.5743463039398193
# spatial_consistency_loss: 1.0943981409072876
# exposure_control_loss: 3.197094202041626
# color_constancy_loss: 1.4432242778639193e-06
# illumination_smoothness_loss: 2.1637565350562937e-10
#
#
# val_loss: 4.286703586578369
# val_DCP-loss: 0.31824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 4.230146441464022e-11
#
#
# Saving model at epoch 40...
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Saved model at epoch 40

# %%
psnr=[]
ssim=[]
resize_imghigh=[]
resize_imglow=[]
print(os.listdir("validate/high15/"))
for img_h in os.listdir("validate/high15/"):
  #print(type(img_h))
  img_re=cv2.imread("validate/high15/"+img_h)
  res = cv2.resize(img_re, dsize=(512,512), interpolation=cv2.INTER_CUBIC)
  #print(res.shape)
  resize_imghigh.append(res)

for img_l in os.listdir("output/validate/"):
  img_re=cv2.imread("output/validate/"+img_l)
  res = cv2.resize(img_re, dsize=(512,512), interpolation=cv2.INTER_CUBIC)
  #print(res.shape)
  resize_imglow.append(res)

for img_true,img_test in zip(resize_imghigh,resize_imglow):
  psnr.append(metrics.peak_signal_noise_ratio(img_true,img_test))
  ssim.append(metrics.structural_similarity(img_true,img_test,multichannel=True))
# Out:
# ['111.png', '780.png', '778.png', '79.png', '22.png', '493.png', '669.png', '23.png', '547.png', '179.png', '55.png', '665.png', '146.png', '1.png', '748.png']

# %%
import pandas as pd
metrics_df=pd.DataFrame(list(zip(psnr,ssim)),columns=['PSNR','SSIM'])

# %%
metrics_df
# Out:
#         PSNR      SSIM
# 0   7.047169  0.548463
# 1   2.621058  0.244541
# 2   4.939814  0.071449
# 3   8.041169  0.342015
# 4   5.625899  0.382091
# 5   2.815424  0.180565
# 6   6.268335  0.398966
# 7   6.816985  0.253473
# 8   5.156609  0.188595
# 9   3.052501  0.222098
# 10  7.544886  0.177396
# 11  6.555594  0.282336
# 12  6.430824  0.367064
# 13  4.864751  0.354893
# 14  3.915168  0.274072

# %%
#data size of 56 with dcp added as loss-> (w=0.001)*(1-dcp)
average_psnr=sum(psnr)/len(psnr)
print("Average PSNR:",round(average_psnr,2))

average_ssim=sum(ssim)/len(ssim)
print("Average SSIM:",round(average_ssim,2))
# Out:
# Average PSNR: 5.45
# Average SSIM: 0.29

# %% [markdown]
# #DCP_loss with weight=0.1

# %%
"""Parameters
weights of DCP_loss=0.1
      Dataset_size=56
      Epoch=40
      learning rate=1e-3
      filters=32
        """

# !python train_model.py --dataset_dir dataset_v/ \
                       --model_type zero_dce \
                       --checkpoint_dir Trained_model \
                       --IMG_H 512 \
                       --IMG_W 512 \
                       --epoch 40\
                       --batch_size 4 \
                       --learning_rate 0.001 \
                       --filters 32 \
                       --iteration 8
# Out:
# Creating dataset pipeline...
#
# Creating Zero-DCE model...
#
# Compiling the model...
#
# [INFO] Summary of model
#
# Model: "DCE-net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 512, 512, 64  0           ['conv2d_2[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 512, 512, 32  18464       ['concatenate[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_1[0][0]',
#                                 )                                 'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 512, 512, 32  18464       ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 512, 512, 64  0           ['conv2d[0][0]',
#                                 )                                 'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 24  13848       ['concatenate_2[0][0]']
#                                 )
#
#  tf.math.square (TFOpLambda)    (None, 512, 512, 3)  0           ['input_1[0][0]']
#
#  tf.split (TFOpLambda)          [(None, 512, 512, 3  0           ['conv2d_6[0][0]']
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 )]
#
#  tf.math.subtract (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.math.square[0][0]',
#                                                                   'input_1[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.split[0][0]',
#                                                                   'tf.math.subtract[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 512, 512, 3)  0          ['input_1[0][0]',
#  da)                                                              'tf.math.multiply[0][0]']
#
#  tf.math.square_1 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_1[0][0]',
#  )                                                                'tf.__operators__.add[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][1]',
#  )                                                                'tf.math.subtract_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add[0][0]',
#  mbda)                                                            'tf.math.multiply_1[0][0]']
#
#  tf.math.square_2 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_2[0][0]',
#  )                                                                'tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][2]',
#  )                                                                'tf.math.subtract_2[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_1[0][0]',
#  mbda)                                                            'tf.math.multiply_2[0][0]']
#
#  tf.math.square_3 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_3[0][0]',
#  )                                                                'tf.__operators__.add_2[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][3]',
#  )                                                                'tf.math.subtract_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'tf.math.multiply_3[0][0]']
#
#  tf.math.square_4 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_4[0][0]',
#  )                                                                'tf.__operators__.add_3[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][4]',
#  )                                                                'tf.math.subtract_4[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_3[0][0]',
#  mbda)                                                            'tf.math.multiply_4[0][0]']
#
#  tf.math.square_5 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.subtract_5 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_5[0][0]',
#  )                                                                'tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][5]',
#  )                                                                'tf.math.subtract_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_4[0][0]',
#  mbda)                                                            'tf.math.multiply_5[0][0]']
#
#  tf.math.square_6 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_5[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_6[0][0]',
#  )                                                                'tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][6]',
#  )                                                                'tf.math.subtract_6[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_5[0][0]',
#  mbda)                                                            'tf.math.multiply_6[0][0]']
#
#  tf.math.square_7 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_6[0][0]']
#
#  tf.math.subtract_7 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_7[0][0]',
#  )                                                                'tf.__operators__.add_6[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][7]',
#  )                                                                'tf.math.subtract_7[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_6[0][0]',
#  mbda)                                                            'tf.math.multiply_7[0][0]']
#
# ==================================================================================================
# Total params: 79,416
# Trainable params: 79,416
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
#
#
# ************************************************************
# 			Model Configs
# ************************************************************
#
#  Model Name                : DCE-Net
#  Input shape               : ((512, 512, 3))
#  Epochs                    : 40
#  Batch Size                : 4
#  Learning Rate             : 0.001
#  Dataset Split             : 0.05
#  Post enhancing Iteration  : 8
#
#
# Training the model...
#
# training...: 100% 13/13 [00:09<00:00,  1.34steps/s]
# validating...: 100% 1/1 [00:00<00:00,  1.12steps/s]
# ETA:0.18 - epoch: 1 - loss: 426.86383056640625  val_loss: 128.43325805664062
#
# Writing logs to TensorBoard...
#
# loss: 426.86383056640625
# DCP-loss: 341.95751953125
# spatial_consistency_loss: 0.820965588092804
# exposure_control_loss: 3.1979572772979736
# color_constancy_loss: 6.354383685902576e-07
# illumination_smoothness_loss: 80.88739013671875
#
#
# val_loss: 128.43325805664062
# val_DCP-loss: 37.17314147949219
# val_spatial_consistency_loss: 0.7686119079589844
# val_exposure_control_loss: 3.199730396270752
# val_color_constancy_loss: 9.74886749105508e-09
# val_illumination_smoothness_loss: 87.29177856445312
#
#
# training...: 100% 13/13 [00:02<00:00,  4.41steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.28steps/s]
# ETA:0.05 - epoch: 2 - loss: 544.3655395507812  val_loss: 35.793121337890625
#
# Writing logs to TensorBoard...
#
# loss: 544.3655395507812
# DCP-loss: 540.3255004882812
# spatial_consistency_loss: 0.8431336879730225
# exposure_control_loss: 3.1968836784362793
# color_constancy_loss: 2.046418103418546e-06
# illumination_smoothness_loss: 4.3640797230182216e-05
#
#
# val_loss: 35.793121337890625
# val_DCP-loss: 31.824665069580078
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 1.3356904915440282e-08
#
#
# training...: 100% 13/13 [00:02<00:00,  4.45steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.23steps/s]
# ETA:0.05 - epoch: 3 - loss: 95.68997955322266  val_loss: 35.79311752319336
#
# Writing logs to TensorBoard...
#
# loss: 95.68997955322266
# DCP-loss: 91.74067687988281
# spatial_consistency_loss: 0.7494125366210938
# exposure_control_loss: 3.19989013671875
# color_constancy_loss: 3.306991347429289e-09
# illumination_smoothness_loss: 2.2827166928072497e-14
#
#
# val_loss: 35.79311752319336
# val_DCP-loss: 31.824661254882812
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 2.956887325592482e-14
#
#
# training...: 100% 13/13 [00:02<00:00,  4.43steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.21steps/s]
# ETA:0.05 - epoch: 4 - loss: 93.81593322753906  val_loss: 35.79311752319336
#
# Writing logs to TensorBoard...
#
# loss: 93.81593322753906
# DCP-loss: 89.92082977294922
# spatial_consistency_loss: 0.6951754689216614
# exposure_control_loss: 3.199925184249878
# color_constancy_loss: 2.1349364498490786e-09
# illumination_smoothness_loss: 0.0
#
#
# val_loss: 35.79311752319336
# val_DCP-loss: 31.824661254882812
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.0
#
#
# training...: 100% 13/13 [00:02<00:00,  4.44steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.18steps/s]
# ETA:0.05 - epoch: 5 - loss: 1233.5421142578125  val_loss: 35.79311752319336
#
# Writing logs to TensorBoard...
#
# loss: 1233.5421142578125
# DCP-loss: 1229.4146728515625
# spatial_consistency_loss: 0.9636569023132324
# exposure_control_loss: 3.163543701171875
# color_constancy_loss: 0.00024911563377827406
# illumination_smoothness_loss: 1.596276721915757e-10
#
#
# val_loss: 35.79311752319336
# val_DCP-loss: 31.824661254882812
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.0
#
#
# training...: 100% 13/13 [00:02<00:00,  4.41steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.19steps/s]
# ETA:0.05 - epoch: 6 - loss: 177.34732055664062  val_loss: 35.79311752319336
#
# Writing logs to TensorBoard...
#
# loss: 177.34732055664062
# DCP-loss: 173.216552734375
# spatial_consistency_loss: 0.9334822297096252
# exposure_control_loss: 3.1972899436950684
# color_constancy_loss: 1.4387646842806134e-06
# illumination_smoothness_loss: 3.289028077668732e-11
#
#
# val_loss: 35.79311752319336
# val_DCP-loss: 31.824661254882812
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.0
#
#
# training...: 100% 13/13 [00:02<00:00,  4.42steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.16steps/s]
# ETA:0.05 - epoch: 7 - loss: 154.3896942138672  val_loss: 35.793121337890625
#
# Writing logs to TensorBoard...
#
# loss: 154.3896942138672
# DCP-loss: 150.2261199951172
# spatial_consistency_loss: 0.9640551209449768
# exposure_control_loss: 3.199522018432617
# color_constancy_loss: 3.2734529753497554e-08
# illumination_smoothness_loss: 3.549446977654802e-13
#
#
# val_loss: 35.793121337890625
# val_DCP-loss: 31.824665069580078
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.0
#
#
# training...: 100% 13/13 [00
val_loss: 35.79311752319336
#
# Writing logs to TensorBoard...
#
# loss: 119.62864685058594
# DCP-loss: 115.56514739990234
# spatial_consistency_loss: 0.8637943863868713
# exposure_control_loss: 3.1997063159942627
# color_constancy_loss: 1.2893197620655883e-08
# illumination_smoothness_loss: 2.0307900868744844e-13
#
#
# val_loss: 35.79311752319336
# val_DCP-loss: 31.824661254882812
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.0
#
#
# training...: 100% 13/13 [00:03<00:00,  4.29steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.05steps/s]
# ETA:0.05 - epoch: 36 - loss: 171.6107177734375  val_loss: 35.793121337890625
#
# Writing logs to TensorBoard...
#
# loss: 171.6107177734375
# DCP-loss: 167.50296020507812
# spatial_consistency_loss: 0.9099326133728027
# exposure_control_loss: 3.197829484939575
# color_constancy_loss: 1.3542010037781438e-06
# illumination_smoothness_loss: 2.406160860835005e-11
#
#
# val_loss: 35.793121337890625
# val_DCP-loss: 31.824665069580078
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.0
#
#
# training...: 100% 13/13 [00:03<00:00,  4.27steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.04steps/s]
# ETA:0.05 - epoch: 37 - loss: 203.42047119140625  val_loss: 35.79311752319336
#
# Writing logs to TensorBoard...
#
# loss: 203.42047119140625
# DCP-loss: 199.39752197265625
# spatial_consistency_loss: 0.8234131932258606
# exposure_control_loss: 3.1995365619659424
# color_constancy_loss: 2.9167306792032832e-08
# illumination_smoothness_loss: 0.0
#
#
# val_loss: 35.79311752319336
# val_DCP-loss: 31.824661254882812
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.0
#
#
# training...: 100% 13/13 [00:03<00:00,  4.28steps/s]
# validating...: 100% 1/1 [00:00<00:00,  3.99steps/s]
# ETA:0.05 - epoch: 38 - loss: 289.94842529296875  val_loss: 35.793121337890625
#
# Writing logs to TensorBoard...
#
# loss: 289.94842529296875
# DCP-loss: 285.75921630859375
# spatial_consistency_loss: 0.9912578463554382
# exposure_control_loss: 3.197965145111084
# color_constancy_loss: 6.086479515943211e-07
# illumination_smoothness_loss: 5.419146034690847e-12
#
#
# val_loss: 35.793121337890625
# val_DCP-loss: 31.824665069580078
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.0
#
#
# training...: 100% 13/13 [00:03<00:00,  4.25steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.07steps/s]
# ETA:0.06 - epoch: 39 - loss: 204.5789031982422  val_loss: 35.793121337890625
#
# Writing logs to TensorBoard...
#
# loss: 204.5789031982422
# DCP-loss: 200.53147888183594
# spatial_consistency_loss: 0.8479363322257996
# exposure_control_loss: 3.199493885040283
# color_constancy_loss: 3.1519821419578875e-08
# illumination_smoothness_loss: 1.892407764712378e-15
#
#
# val_loss: 35.793121337890625
# val_DCP-loss: 31.824665069580078
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.0
#
#
# training...: 100% 13/13 [00:03<00:00,  4.27steps/s]
# validating...: 100% 1/1 [00:00<00:00,  3.98steps/s]
# ETA:0.05 - epoch: 40 - loss: 261.72613525390625  val_loss: 35.79311752319336
#
# Writing logs to TensorBoard...
#
# loss: 261.72613525390625
# DCP-loss: 257.43463134765625
# spatial_consistency_loss: 1.0943982601165771
# exposure_control_loss: 3.197094202041626
# color_constancy_loss: 1.4432242778639193e-06
# illumination_smoothness_loss: 2.8358912440573647e-11
#
#
# val_loss: 35.79311752319336
# val_DCP-loss: 31.824661254882812
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.0
#
#
# Saving model at epoch 40...
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Saved model at epoch 40

# %%
psnr=[]
ssim=[]
resize_imghigh=[]
resize_imglow=[]
print(os.listdir("validate/high15/"))
for img_h in os.listdir("validate/high15/"):
  #print(type(img_h))
  img_re=cv2.imread("validate/high15/"+img_h)
  res = cv2.resize(img_re, dsize=(512,512), interpolation=cv2.INTER_CUBIC)
  #print(res.shape)
  resize_imghigh.append(res)

for img_l in os.listdir("output/validate/"):
  img_re=cv2.imread("output/validate/"+img_l)
  res = cv2.resize(img_re, dsize=(512,512), interpolation=cv2.INTER_CUBIC)
  #print(res.shape)
  resize_imglow.append(res)

for img_true,img_test in zip(resize_imghigh,resize_imglow):
  psnr.append(metrics.peak_signal_noise_ratio(img_true,img_test))
  ssim.append(metrics.structural_similarity(img_true,img_test,multichannel=True))
# Out:
# ['111.png', '780.png', '778.png', '79.png', '22.png', '493.png', '669.png', '23.png', '547.png', '179.png', '55.png', '665.png', '146.png', '1.png', '748.png']

# %%
import pandas as pd
metrics_df=pd.DataFrame(list(zip(psnr,ssim)),columns=['PSNR','SSIM'])

# %%
metrics_df
# Out:
#         PSNR      SSIM
# 0   7.047170  0.548463
# 1   2.621058  0.244541
# 2   4.939814  0.071449
# 3   8.041170  0.342016
# 4   5.625898  0.382090
# 5   2.815423  0.180565
# 6   6.268335  0.398966
# 7   6.816985  0.253473
# 8   5.156609  0.188595
# 9   3.052501  0.222098
# 10  7.544887  0.177397
# 11  6.555593  0.282336
# 12  6.430824  0.367064
# 13  4.864751  0.354893
# 14  3.915168  0.274072

# %%
#data size of 56 with dcp added as loss-> (w=0.1)*(1-dcp)
average_psnr=sum(psnr)/len(psnr)
print("Average PSNR:",round(average_psnr,2))

average_ssim=sum(ssim)/len(ssim)
print("Average SSIM:",round(average_ssim,2))
# Out:
# Average PSNR: 5.45
# Average SSIM: 0.29

# %% [markdown]
# #DCP_loss with weight=0.0001

# %%
"""Parameters
weights of DCP_loss=0.0001
      Dataset_size=56
      Epoch=40
      learning rate=1e-3
      filters=32
        """

# !python train_model.py --dataset_dir dataset_v/ \
                       --model_type zero_dce \
                       --checkpoint_dir Trained_model/ \
                       --IMG_H 512 \
                       --IMG_W 512 \
                       --epoch 40\
                       --batch_size 4 \
                       --learning_rate 0.001 \
                       --filters 32 \
                       --iteration 8
# Out:
# Creating dataset pipeline...
#
# Creating Zero-DCE model...
#
# Compiling the model...
#
# [INFO] Summary of model
#
# Model: "DCE-net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 512, 512, 64  0           ['conv2d_2[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 512, 512, 32  18464       ['concatenate[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_1[0][0]',
#                                 )                                 'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 512, 512, 32  18464       ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 512, 512, 64  0           ['conv2d[0][0]',
#                                 )                                 'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 24  13848       ['concatenate_2[0][0]']
#                                 )
#
#  tf.math.square (TFOpLambda)    (None, 512, 512, 3)  0           ['input_1[0][0]']
#
#  tf.split (TFOpLambda)          [(None, 512, 512, 3  0           ['conv2d_6[0][0]']
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 ),
#                                  (None, 512, 512, 3
#                                 )]
#
#  tf.math.subtract (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.math.square[0][0]',
#                                                                   'input_1[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.split[0][0]',
#                                                                   'tf.math.subtract[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 512, 512, 3)  0          ['input_1[0][0]',
#  da)                                                              'tf.math.multiply[0][0]']
#
#  tf.math.square_1 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_1[0][0]',
#  )                                                                'tf.__operators__.add[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][1]',
#  )                                                                'tf.math.subtract_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add[0][0]',
#  mbda)                                                            'tf.math.multiply_1[0][0]']
#
#  tf.math.square_2 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_2[0][0]',
#  )                                                                'tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][2]',
#  )                                                                'tf.math.subtract_2[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_1[0][0]',
#  mbda)                                                            'tf.math.multiply_2[0][0]']
#
#  tf.math.square_3 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_3[0][0]',
#  )                                                                'tf.__operators__.add_2[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][3]',
#  )                                                                'tf.math.subtract_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'tf.math.multiply_3[0][0]']
#
#  tf.math.square_4 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_4[0][0]',
#  )                                                                'tf.__operators__.add_3[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][4]',
#  )                                                                'tf.math.subtract_4[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_3[0][0]',
#  mbda)                                                            'tf.math.multiply_4[0][0]']
#
#  tf.math.square_5 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.subtract_5 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_5[0][0]',
#  )                                                                'tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][5]',
#  )                                                                'tf.math.subtract_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_4[0][0]',
#  mbda)                                                            'tf.math.multiply_5[0][0]']
#
#  tf.math.square_6 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_5[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_6[0][0]',
#  )                                                                'tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][6]',
#  )                                                                'tf.math.subtract_6[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_5[0][0]',
#  mbda)                                                            'tf.math.multiply_6[0][0]']
#
#  tf.math.square_7 (TFOpLambda)  (None, 512, 512, 3)  0           ['tf.__operators__.add_6[0][0]']
#
#  tf.math.subtract_7 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.math.square_7[0][0]',
#  )                                                                'tf.__operators__.add_6[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 512, 512, 3)  0          ['tf.split[0][7]',
#  )                                                                'tf.math.subtract_7[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 512, 512, 3)  0          ['tf.__operators__.add_6[0][0]',
#  mbda)                                                            'tf.math.multiply_7[0][0]']
#
# ==================================================================================================
# Total params: 79,416
# Trainable params: 79,416
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
#
#
# ************************************************************
# 			Model Configs
# ************************************************************
#
#  Model Name                : DCE-Net
#  Input shape               : ((512, 512, 3))
#  Epochs                    : 40
#  Batch Size                : 4
#  Learning Rate             : 0.001
#  Dataset Split             : 0.05
#  Post enhancing Iteration  : 8
#
#
# Training the model...
#
# training...: 100% 13/13 [00:09<00:00,  1.34steps/s]
# validating...: 100% 1/1 [00:00<00:00,  1.11steps/s]
# ETA:0.18 - epoch: 1 - loss: 102.89311981201172  val_loss: 57.155372619628906
#
# Writing logs to TensorBoard...
#
# loss: 102.89311981201172
# DCP-loss: 85.77205657958984
# spatial_consistency_loss: 0.010380048304796219
# exposure_control_loss: 2.588852643966675
# color_constancy_loss: 0.024192120879888535
# illumination_smoothness_loss: 14.497637748718262
#
#
# val_loss: 57.155372619628906
# val_DCP-loss: 39.611854553222656
# val_spatial_consistency_loss: 0.01466815173625946
# val_exposure_control_loss: 2.521585464477539
# val_color_constancy_loss: 0.012169684283435345
# val_illumination_smoothness_loss: 14.995095252990723
#
#
# training...: 100% 13/13 [00:02<00:00,  4.45steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.17steps/s]
# ETA:0.05 - epoch: 2 - loss: 84.31961059570312  val_loss: 48.59550476074219
#
# Writing logs to TensorBoard...
#
# loss: 84.31961059570312
# DCP-loss: 67.61192321777344
# spatial_consistency_loss: 0.10980979353189468
# exposure_control_loss: 1.3626246452331543
# color_constancy_loss: 0.06707893311977386
# illumination_smoothness_loss: 15.168174743652344
#
#
# val_loss: 48.59550476074219
# val_DCP-loss: 30.249271392822266
# val_spatial_consistency_loss: 0.11315491050481796
# val_exposure_control_loss: 1.5054306983947754
# val_color_constancy_loss: 0.06758511811494827
# val_illumination_smoothness_loss: 16.660062789916992
#
#
# training...: 100% 13/13 [00:02<00:00,  4.45steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.22steps/s]
# ETA:0.05 - epoch: 3 - loss: 58.338584899902344  val_loss: 39.857872009277344
#
# Writing logs to TensorBoard...
#
# loss: 58.338584899902344
# DCP-loss: 38.842674255371094
# spatial_consistency_loss: 0.3242700397968292
# exposure_control_loss: 1.0872882604599
# color_constancy_loss: 0.09680696576833725
# illumination_smoothness_loss: 17.987546920776367
#
#
# val_loss: 39.857872009277344
# val_DCP-loss: 17.746912002563477
# val_spatial_consistency_loss: 0.3410734236240387
# val_exposure_control_loss: 1.4162166118621826
# val_color_constancy_loss: 0.058760758489370346
# val_illumination_smoothness_loss: 20.29490852355957
#
#
# training...: 100% 13/13 [00:02<00:00,  4.42steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.16steps/s]
# ETA:0.05 - epoch: 4 - loss: 7.543128490447998  val_loss: 6.080292701721191
#
# Writing logs to TensorBoard...
#
# loss: 7.543128490447998
# DCP-loss: 0.19005173444747925
# spatial_consistency_loss: 0.6949658393859863
# exposure_control_loss: 3.198596954345703
# color_constancy_loss: 3.826859256150783e-07
# illumination_smoothness_loss: 3.4595139026641846
#
#
# val_loss: 6.080292701721191
# val_DCP-loss: 0.0597417838871479
# val_spatial_consistency_loss: 0.768315315246582
# val_exposure_control_loss: 3.1978940963745117
# val_color_constancy_loss: 7.897583600424696e-07
# val_illumination_smoothness_loss: 2.054340362548828
#
#
# training...: 100% 13/13 [00:02<00:00,  4.43steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.22steps/s]
# ETA:0.05 - epoch: 5 - loss: 5.357663154602051  val_loss: 4.000520706176758
#
# Writing logs to TensorBoard...
#
# loss: 5.357663154602051
# DCP-loss: 1.2294763326644897
# spatial_consistency_loss: 0.9636566042900085
# exposure_control_loss: 3.1635422706604004
# color_constancy_loss: 0.00024913394008763134
# illumination_smoothness_loss: 0.0007392796687781811
#
#
# val_loss: 4.000520706176758
# val_DCP-loss: 0.031824756413698196
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 0.00023923235130496323
#
#
# training...: 100% 13/13 [00:02<00:00,  4.54steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.33steps/s]
# ETA:0.05 - epoch: 6 - loss: 4.303998947143555  val_loss: 4.000284194946289
#
# Writing logs to TensorBoard...
#
# loss: 4.303998947143555
# DCP-loss: 0.1732165664434433
# spatial_consistency_loss: 0.9334822297096252
# exposure_control_loss: 3.1972899436950684
# color_constancy_loss: 1.4387646842806134e-06
# illumination_smoothness_loss: 8.875675121089444e-06
#
#
# val_loss: 4.000284194946289
# val_DCP-loss: 0.031824659556150436
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 2.5507399641355732e-06
#
#
# training...: 100% 13/13 [00:02<00:00,  4.58steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.30steps/s]
# ETA:0.05 - epoch: 7 - loss: 4.313803672790527  val_loss: 4.000282287597656
#
# Writing logs to TensorBoard...
#
# loss: 4.313803672790527
# DCP-loss: 0.15022610127925873
# spatial_consistency_loss: 0.9640551209449768
# exposure_control_loss: 3.199522018432617
# color_constancy_loss: 3.2734529753497554e-08
# illumination_smoothness_loss: 3.366107819147146e-07
#
#
# val_loss: 4.000282287597656
# val_DCP-loss: 0.031824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 5.337500397217809e-07
#
#
# training...: 100% 13/13 [00:02<00:00,  4.56steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.24steps/s]
# ETA:0.05 - epoch: 8 - loss: 4.285286903381348  val_loss: 4.000281810760498
#
# Writing logs to TensorBoard...
#
# loss: 4
ps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.13steps/s]
# ETA:0.05 - epoch: 35 - loss: 4.1790666580200195  val_loss: 4.000281810760498
#
# Writing logs to TensorBoard...
#
# loss: 4.1790666580200195
# DCP-loss: 0.11556514352560043
# spatial_consistency_loss: 0.8637943863868713
# exposure_control_loss: 3.1997063159942627
# color_constancy_loss: 1.2893197620655883e-08
# illumination_smoothness_loss: 2.7021346227229515e-07
#
#
# val_loss: 4.000281810760498
# val_DCP-loss: 0.031824659556150436
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 2.8221322168064944e-07
#
#
# training...: 100% 13/13 [00:02<00:00,  4.48steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.21steps/s]
# ETA:0.05 - epoch: 36 - loss: 4.275267124176025  val_loss: 4.000281810760498
#
# Writing logs to TensorBoard...
#
# loss: 4.275267124176025
# DCP-loss: 0.16750295460224152
# spatial_consistency_loss: 0.9099326133728027
# exposure_control_loss: 3.197829484939575
# color_constancy_loss: 1.3542010037781438e-06
# illumination_smoothness_loss: 4.868587666351232e-07
#
#
# val_loss: 4.000281810760498
# val_DCP-loss: 0.031824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 2.820854092533409e-07
#
#
# training...: 100% 13/13 [00:02<00:00,  4.48steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.24steps/s]
# ETA:0.05 - epoch: 37 - loss: 4.222347259521484  val_loss: 4.000281810760498
#
# Writing logs to TensorBoard...
#
# loss: 4.222347259521484
# DCP-loss: 0.1993975192308426
# spatial_consistency_loss: 0.8234131932258606
# exposure_control_loss: 3.1995365619659424
# color_constancy_loss: 2.9167306792032832e-08
# illumination_smoothness_loss: 1.398387183826344e-07
#
#
# val_loss: 4.000281810760498
# val_DCP-loss: 0.031824659556150436
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 2.8195515255902137e-07
#
#
# training...: 100% 13/13 [00:02<00:00,  4.47steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.25steps/s]
# ETA:0.05 - epoch: 38 - loss: 4.474983215332031  val_loss: 4.000281810760498
#
# Writing logs to TensorBoard...
#
# loss: 4.474983215332031
# DCP-loss: 0.28575921058654785
# spatial_consistency_loss: 0.9912578463554382
# exposure_control_loss: 3.197965145111084
# color_constancy_loss: 6.086479515943211e-07
# illumination_smoothness_loss: 4.998803433409194e-07
#
#
# val_loss: 4.000281810760498
# val_DCP-loss: 0.031824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 2.81842801541643e-07
#
#
# training...: 100% 13/13 [00:02<00:00,  4.48steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.13steps/s]
# ETA:0.05 - epoch: 39 - loss: 4.24796199798584  val_loss: 4.000281810760498
#
# Writing logs to TensorBoard...
#
# loss: 4.24796199798584
# DCP-loss: 0.200531467795372
# spatial_consistency_loss: 0.8479363322257996
# exposure_control_loss: 3.199493885040283
# color_constancy_loss: 3.1519821419578875e-08
# illumination_smoothness_loss: 4.124260897242493e-07
#
#
# val_loss: 4.000281810760498
# val_DCP-loss: 0.031824663281440735
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 2.8172863153486105e-07
#
#
# training...: 100% 13/13 [00:02<00:00,  4.47steps/s]
# validating...: 100% 1/1 [00:00<00:00,  4.30steps/s]
# ETA:0.05 - epoch: 40 - loss: 4.548929214477539  val_loss: 4.000281810760498
#
# Writing logs to TensorBoard...
#
# loss: 4.548929214477539
# DCP-loss: 0.257434606552124
# spatial_consistency_loss: 1.0943982601165771
# exposure_control_loss: 3.197094202041626
# color_constancy_loss: 1.4432242778639193e-06
# illumination_smoothness_loss: 1.022473497869214e-06
#
#
# val_loss: 4.000281810760498
# val_DCP-loss: 0.031824659556150436
# val_spatial_consistency_loss: 0.7686281800270081
# val_exposure_control_loss: 3.199828863143921
# val_color_constancy_loss: 2.991164649301936e-09
# val_illumination_smoothness_loss: 2.815829418523208e-07
#
#
# Saving model at epoch 40...
#
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Saved model at epoch 40

# %%
psnr=[]
ssim=[]
resize_imghigh=[]
resize_imglow=[]
print(os.listdir("validate/high15/"))
for img_h in os.listdir("validate/high15/"):
  #print(type(img_h))
  img_re=cv2.imread("validate/high15/"+img_h)
  res = cv2.resize(img_re, dsize=(512,512), interpolation=cv2.INTER_CUBIC)
  #print(res.shape)
  resize_imghigh.append(res)

for img_l in os.listdir("output/validate/"):
  img_re=cv2.imread("output/validate/"+img_l)
  res = cv2.resize(img_re, dsize=(512,512), interpolation=cv2.INTER_CUBIC)
  #print(res.shape)
  resize_imglow.append(res)

for img_true,img_test in zip(resize_imghigh,resize_imglow):
  psnr.append(metrics.peak_signal_noise_ratio(img_true,img_test))
  ssim.append(metrics.structural_similarity(img_true,img_test,multichannel=True))
# Out:
# ['111.png', '780.png', '778.png', '79.png', '22.png', '493.png', '669.png', '23.png', '547.png', '179.png', '55.png', '665.png', '146.png', '1.png', '748.png']

# %%
import pandas as pd
metrics_df=pd.DataFrame(list(zip(psnr,ssim)),columns=['PSNR','SSIM'])

# %%
metrics_df
# Out:
#         PSNR      SSIM
# 0   7.047170  0.548463
# 1   2.621058  0.244541
# 2   4.939814  0.071449
# 3   8.041170  0.342016
# 4   5.625898  0.382090
# 5   2.815423  0.180565
# 6   6.268335  0.398966
# 7   6.816985  0.253473
# 8   5.156609  0.188595
# 9   3.052501  0.222098
# 10  7.544887  0.177397
# 11  6.555593  0.282336
# 12  6.430824  0.367064
# 13  4.864751  0.354893
# 14  3.915168  0.274072

# %%
#data size of 56 with dcp added as loss-> (w=0.0001)*(1-dcp)
average_psnr=sum(psnr)/len(psnr)
print("Average PSNR:",round(average_psnr,2))

average_ssim=sum(ssim)/len(ssim)
print("Average SSIM:",round(average_ssim,2))
# Out:
# Average PSNR: 5.45
# Average SSIM: 0.29

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/1.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7f6d0ecb2d90>
# [info] running inference....
# [info] inference time: 2476.188898086548 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/111.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7f2362754fa0>
# [info] running inference....
# [info] inference time: 2404.050827026367 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/146.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7fdf80fab250>
# [info] running inference....
# [info] inference time: 2363.572835922241 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/179.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7f8dcd98ff40>
# [info] running inference....
# [info] inference time: 2376.0805130004883 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/22.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7fe4c84c9b80>
# [info] running inference....
# [info] inference time: 2365.116596221924 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/23.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7f57e28bc400>
# [info] running inference....
# [info] inference time: 2368.6459064483643 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/493.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7efc8c1f7fd0>
# [info] running inference....
# [info] inference time: 2384.004831314087 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/547.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7f4253d27e50>
# [info] running inference....
# [info] inference time: 2480.13973236084 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/55.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7fcc6bfe4b80>
# [info] running inference....
# [info] inference time: 2389.8706436157227 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/665.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7f0b09abef70>
# [info] running inference....
# [info] inference time: 2338.4041786193848 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/669.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7fdafdb34700>
# [info] running inference....
# [info] inference time: 2387.6290321350098 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/748.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7f6627a10430>
# [info] running inference....
# [info] inference time: 2421.5776920318604 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/778.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7f66000687c0>
# [info] running inference....
# [info] inference time: 2392.9829597473145 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/780.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7f5e56746f40>
# [info] running inference....
# [info] inference time: 2389.836072921753 ms
# [info] saved enhanced image to disk

# %%
! python command_line_scripts/single_image_enhance.py --model_path Trained_model/zero_dce_iter8/zero_dce_512x512_iter8_40 \
                                 --img_h 512 \
                                 --img_w 512 \
                                 --image_path validate/low/79.png \
                                 --plot 0 \
                                 --save_result 1 \
                                 --iteration 8
# Out:
# [info] loading model from disk....
# WARNING:absl:Importing a function (__inference_internal_grad_fn_16648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# loaded model: <keras.saving.saved_model.load.ZeroDCE object at 0x7f3d46a8ccd0>
# [info] running inference....
# [info] inference time: 2429.227590560913 ms
# [info] saved enhanced image to disk
